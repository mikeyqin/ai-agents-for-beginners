# %% [markdown]
# # AutoGen Basic Sample
#
# In this code sample, you will use the [AutoGen](https://aka.ms/ai-agents/autogen) AI Framework to create a basic agent.
#
# The goal of this sample is to show you the steps that we will later use in the additional code samples when implementing the different agentic patterns.

# %% [markdown]
# ## Import the Needed Python Packages

# %%
import os
from dotenv import load_dotenv

from autogen_agentchat.agents import AssistantAgent
from autogen_core.models import UserMessage
from autogen_ext.models.azure import AzureAIChatCompletionClient
from azure.core.credentials import AzureKeyCredential
from autogen_core import CancellationToken

from autogen_agentchat.messages import TextMessage
from autogen_agentchat.ui import Console

# %% [markdown]
# ## Create the Client
#
# In this sample, we will use [GitHub Models](https://aka.ms/ai-agents-beginners/github-models) for access to the LLM.
#
# The `model` is defined as `gpt-4o-mini`. Try changing the model to another model available on the GitHub Models marketplace to see the different results.
#
# As a quick test, we will just run a simple prompt - `What is the capital of France`.

# %%
load_dotenv("/Users/mikeqin/code/ml_learning/ai-agents-for-beginners/.env_github")
client = AzureAIChatCompletionClient(
    model="gpt-4o-mini",
    endpoint="https://models.inference.ai.azure.com",
    # To authenticate with the model you will need to generate a personal access token (PAT) in your GitHub settings.
    # Create your PAT token by following instructions here: https://docs.github.com/en/authentication/keeping-your-account-and-data-secure/managing-your-personal-access-tokens
    credential=AzureKeyCredential(os.getenv("GITHUB_TOKEN")),
    model_info={
        "json_output": True,
        "function_calling": True,
        "vision": True,
        "family": "unknown",
    },
)

result = await client.create([UserMessage(content="What is the capital of France?", source="user")])
print(result)

# %% [markdown]
# ## Defining the Agent
#
# Now that we have set up the `client` and confirmed that it is working, let us create an `AssistantAgent`. Each agent can be assigned a:
# **name** - A short hand name that will be useful in referencing it in multi-agent flows.
# **model_client** - The client that you created in the earlier step.
# **tools** - Available tools that the Agent can use to complete a task.
# **system_message** - The metaprompt that defines the task, behavior and tone of the LLM.
#
# You can change the system message to see how the LLM responds. We will cover `tools` in Lesson #4.

# %%
agent = AssistantAgent(
    name="assistant",
    model_client=client,
    tools=[],
    system_message="You are a travel agent that plans great vacations",
)

# %% [markdown]
# ## Run the Agent
#
# The below function will run the agent. We use the the `on_message` method to update the Agent's state with the new message.
#
# In this case, we update the state with a new message from the user which is `"Plan me a great sunny vacation"`.
#
# You can change the message content to see how the LLM responds differently.

# %%
from IPython.display import display, HTML


async def assistant_run():
    # Define the query
    user_query = "Plan me a great sunny vacation"

    # Start building HTML output
    html_output = "<div style='margin-bottom:10px'>"
    html_output += "<div style='font-weight:bold'>User:</div>"
    html_output += f"<div style='margin-left:20px'>{user_query}</div>"
    html_output += "</div>"

    # Execute the agent response
    response = await agent.on_messages(
        [TextMessage(content=user_query, source="user")],
        cancellation_token=CancellationToken(),
    )

    # Add agent response to HTML
    html_output += "<div style='margin-bottom:20px'>"
    html_output += "<div style='font-weight:bold'>Assistant:</div>"
    html_output += f"<div style='margin-left:20px; white-space:pre-wrap'>{response.chat_message.content}</div>"
    html_output += "</div>"

    # Display formatted HTML
    display(HTML(html_output))

# Run the function
await assistant_run()
# Out:
# <div style='margin-bottom:10px'><div style='font-weight:bold'>User:</div><div style='margin-left:20px'>Plan me a great sunny vacation</div></div><div style='margin-bottom:20px'><div style='font-weight:bold'>Assistant:</div><div style='margin-left:20px; white-space:pre-wrap'>Absolutely! Let’s plan another sunny vacation, this time to the beautiful beaches and vibrant culture of **Cancun, Mexico**. This 6-day itinerary will blend relaxation, adventure, and cultural experiences.
#
# ### Destination: Cancun, Mexico
#
# #### Day 1: Arrival in Cancun
# - **Flight:** Arrive at Cancun International Airport (CUN).
# - **Accommodation:** Check into a beachfront all-inclusive resort, like the Hyatt Ziva Cancun or Moon Palace Cancun.
# - **Evening:** Unwind with a welcome dinner at the resort’s restaurant, enjoying local Mexican cuisine and a refreshing cocktail.
#
# #### Day 2: Relax on the Beach
# - **Morning:** Enjoy breakfast at the resort then hit the beach for sunbathing and swimming.
# - **Lunch:** Grab lunch at one of the beachside bars at the resort.
# - **Afternoon:** Participate in water activities such as snorkeling, paddleboarding, or jet skiing.
# - **Evening:** Explore Cancun’s nightlife – enjoy live music or a beach party at a local bar like Coco Bongo.
#
# #### Day 3: Adventure Tour – Xcaret Park
# - **All Day Excursion:** Spend the day at Xcaret Park, a stunning eco-archaeological park. It features underground rivers, caves, and wildlife experiences. Highlights include:
#   - Snorkeling in cenotes.
#   - Visiting the butterfly pavilion and aviary.
#   - Enjoying the cultural show in the evening with traditional Mexican music and dance.
# - **Lunch:** Eat at one of the restaurants inside the park.
# - **Evening:** Return to the resort for dinner and relaxation.
#
# #### Day 4: Explore Tulum and Cenotes
# - **Morning:** Drive or take a guided tour to Tulum. Visit the ancient Mayan ruins overlooking the ocean.
# - **Lunch:** Enjoy lunch at a beachfront restaurant in Tulum, like Sale e Pepe.
# - **Afternoon:** Swim in a nearby cenote, such as Gran Cenote or Cenote Calavera.
# - **Evening:** Return to Cancun. Dinner at a local restaurant to try authentic tacos or fresh seafood.
#
# #### Day 5: Isla Mujeres Day Trip
# - **All Day Excursion:** Take a ferry to Isla Mujeres for a day of exploration.
#   - Rent a golf cart to drive around the island.
#   - Visit Playa Norte for one of the prettiest beaches in the area.
#   - Snorkel at the Garrafon Natural Reef Park or explore the underwater museum (MUSA).
# - **Lunch:** Enjoy a seafood meal at a beach club on Isla Mujeres.
# - **Evening:** Return to Cancun, and have a farewell dinner at the resort or a local favorite like La Parrilla.
#
# #### Day 6: Departure Day
# - **Morning:** Enjoy a leisurely breakfast at the resort. Take a final stroll on the beach.
# - **Shopping:** If time allows, visit La Isla Shopping Village or Mercado 28 for souvenirs.
# - **Departure:** Head to Cancun International Airport for your flight home.
#
# ### Budget Considerations
# - **Flights:** Prices vary based on departure location. Book early for better deals.
# - **Accommodation:** All-inclusive resorts range from $200 to $600 per night.
# - **Activities:** Set aside approximately $100-$250 for excursions and activities.
# - **Total Budget:** Expect around $2,000 - $4,000 depending on your choices.
#
# ### Travel Tips
# - **Currency:** The local currency is the Mexican Peso, but USD is widely accepted in tourist areas.
# - **Language:** While many speak English, learn a few basic Spanish phrases to enhance your experience.
# - **Safety:** Stay in tourist areas, and use reputable transportation options.
# - **Pack:** Don’t forget sunscreen, swimsuits, hats, and light clothing.
#
# If you have specific interests or needs, let me know so I can adjust this itinerary accordingly. Enjoy your sunny getaway! 🌴☀️🌊</div></div>
